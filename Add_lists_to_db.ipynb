# %%
import os
import pymongo
from pymongo import MongoClient

MONGODB_URI = ('mongodb://root:stargatesg1@ds251332.mlab.com:51332/cookbook')
DBS_NAME = "cookbook"
COLLECTION_NAME = "allergens" #cuisine #categories


def mongo_connect(url):
    try:
        conn = pymongo.MongoClient(url)
        print("mongo is connected")
        return conn
    except pymongo.errors.ConnectionFailure as e:
        print("Not connected: %s") % e

def add_category():
    category = ['Lunch','Dinner','Snacks','Appetisers','Soups','Salads','Rice','Noodles','Pasta','Pies','Chicken','Turkey','Duck','Poultry','Pork','Lamb','Beef','Meat','Seafood','Stir-Fry','Sauces','Vegetarian','Desserts','Baking','Drinks','Vegan','Gluten Free']
    try:
        for cat in category:
            new_cat = {'category_name': cat.lower()}
            coll.insert_one(new_cat)
            print("categories inserted: ", new_cat)
    except pymongo.errors.ConnectionFailure as e:
        print("error accessing DB: %s") % e

def add_cuisine():
    cuisine = ['African','American','Asian','Australian','Brazil','British','Cajun','Chinese','Creole','Danish','European','French','Greek','Hungarian','Indian','Indonesian','Irish','Italian','Jamaica','Japanese','Korean','Lebanese',
 'Malaysian','Mediteranean','Mexican','Middle','East','Norwegian','Portuguese','Russian','Scandinavian','Singaporean','Spanish','Sri','Lankan','Swedish','Thai','Turkish','Vietnamese']
    try:
        for cuis in cuisine:
            new_cuis = {'cuisine_name': cuis.lower()}
            coll.insert_one(new_cuis)
            print("cuisine inserted: ", new_cuis)
    except pymongo.errors.ConnectionFailure as e:
        print("error accessing DB: %s") % e 
        

def add_allergen():
    allergens = ['wheat','rye','barley','oats','crabs','prawns','lobsters','eggs','fish','peanuts','soybeans','milk','almonds','hazelnuts','walnuts','cashews','pecan nuts','brazil nuts','pistachio nuts','macademia','celery','mustard','sesame','seeds','sulphur dioxide','sulphites','lupin','molluscs']
    try:
        for allergen in allergens:
            new_allergen = {'allergen_name': allergen.lower()}
            coll.insert_one(new_allergen)
            print("allergen inserted: ", new_allergen)
    except pymongo.errors.ConnectionFailure as e:
        print("error accessing DB: %s") % e 
        
        
conn = mongo_connect((MONGODB_URI))
coll = conn[DBS_NAME][COLLECTION_NAME]

# add_category()
# add_cuisine()
add_allergen()
# Out:
# mongo is connected
# allergen inserted:  {'allergen_name': 'wheat', '_id': ObjectId('5b96baf680ae4c1dac46702c')}
# allergen inserted:  {'allergen_name': 'rye', '_id': ObjectId('5b96baf780ae4c1dac46702d')}
# allergen inserted:  {'allergen_name': 'barley', '_id': ObjectId('5b96baf780ae4c1dac46702e')}
# allergen inserted:  {'allergen_name': 'oats', '_id': ObjectId('5b96baf780ae4c1dac46702f')}
# allergen inserted:  {'allergen_name': 'crabs', '_id': ObjectId('5b96baf780ae4c1dac467030')}
# allergen inserted:  {'allergen_name': 'prawns', '_id': ObjectId('5b96baf780ae4c1dac467031')}
# allergen inserted:  {'allergen_name': 'lobsters', '_id': ObjectId('5b96baf780ae4c1dac467032')}
# allergen inserted:  {'allergen_name': 'eggs', '_id': ObjectId('5b96baf780ae4c1dac467033')}
# allergen inserted:  {'allergen_name': 'fish', '_id': ObjectId('5b96baf780ae4c1dac467034')}
# allergen inserted:  {'allergen_name': 'peanuts', '_id': ObjectId('5b96baf780ae4c1dac467035')}
# ...
